# %% [markdown]
# <a href="https://colab.research.google.com/github/BakMarino/Dados/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
Base_Dados = sns.load_dataset('iris')

Base_Dados.head()

# %%
Base_Dados.shape
# Out:
# (150, 5)

# %%
Base_Dados['petal_length'].mean()
# Out:
# 3.7580000000000005

# %%
Base_Dados['petal_length'].mode()
# Out:
# 0    1.4
# 1    1.5
# Name: petal_length, dtype: float64

# %%
Base_Dados['petal_length'].median()
# Out:
# 4.35

# %%
# Loja e Sapatos - 1º Semana
1.000, 1.200, 1.400, 1.100, 5.000 / 5
# não é de bom uso tirar a media dessa forma mais a media é sensivel a grandes valores
# fazendo com q a media final fosse 1.940 sendo q nos demais dias não alcançamos esses resultados dando assim um valor esquisito.

# sendo assim utiliza-se a MEDIANA que pode ser encontrada da seguinte forma organiza-se os numeros em ordem crescente ou decrescente
1.000, 1.100, 1.200, 1.400, 5.000
# observa-se nesse caso q poderiamos acusar q 1.200 seria o valor de ticket médio pois se encontra entre os valores comulados
# atente-se sempre para buscar a melhor forma de expor os dados evitando manipulações e discrepancias

# %%
Base_Dados['petal_length'].describe()
# Out:
# count    150.000000
# mean       3.758000
# std        1.765298
# min        1.000000
# 25%        1.600000
# 50%        4.350000
# 75%        5.100000
# max        6.900000
# Name: petal_length, dtype: float64

# %%
sns.boxplot( Base_Dados['sepal_length'] )
# Out:
# <Axes: ylabel='sepal_length'>

# %%
Base_Dados[ 'sepal_length'].max() - Base_Dados[ 'sepal_length'].min()
# Out:
# 3.6000000000000005

# %%
(Base_Dados[ 'sepal_length'].describe()[6:7].values - Base_Dados['sepal_length'].describe()[4:5].values) /2
# Out:
# array([0.65])

# %%
Base_Dados[ 'sepal_length'].var()
# Out:
# 0.6856935123042505

# %%
#Std verifica quao distante esta os dados em relação a mediana, logo o std deve estar o mais proximo e 0 para um resultado confiavel
Base_Dados['sepal_length'].std()
# Out:
# 0.8280661279778629

# %%
Base_Dados[ 'sepal_length'].skew()
# Out:
# 0.3149109566369728

# %%
# nesse caso demonstramos uma media simetrica com a MÉDIA = MEDIANA  = MODA encontrando-se no centro do gráfico
sns.kdeplot(Base_Dados['sepal_length']);

# %%
Base_Dados['sepal_length'].kurtosis()
# Out:
# -0.5520640413156395

# %%
Base_Dados.select_dtypes(include=['float64', 'int64']).corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['sepal_length'].plot(kind='hist', bins=20, title='sepal_length')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['sepal_width'].plot(kind='hist', bins=20, title='sepal_width')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['petal_length'].plot(kind='hist', bins=20, title='petal_length')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
sns.heatmap(Base_Dados.select_dtypes(include=['float64', 'int64']).corr(), annot=True)
# Out:
# <Axes: >

# %%
sns.scatterplot(data=Base_Dados, x='petal_length', y='petal_width')
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
Base_Dados.select_dtypes(include=['float64', 'int64']).corr('spearman')
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.166778      0.881898     0.834289
# sepal_width      -0.166778     1.000000     -0.309635    -0.289032
# petal_length      0.881898    -0.309635      1.000000     0.937667
# petal_width       0.834289    -0.289032      0.937667     1.000000

# %%
sns.heatmap(Base_Dados.select_dtypes(include=['float64', 'int64']).corr('spearman'), annot=True)
# Out:
# <Axes: >

# %%
sns.scatterplot(data=Base_Dados, x='sepal_length', y='petal_width')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_width'>
